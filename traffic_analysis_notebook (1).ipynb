# %%
import traffic_analysis as ta

# %%
traffic_path = "C:/Users/hp/Downloads/Automated_Traffic_Volume_Counts.csv"
events_path = "C:/Users/hp/Downloads/NYC_Permitted_Event_Information_-_Historical.csv"

# %%
traffic_df, events_df = ta.load_and_clean_data(traffic_path, events_path)
merged_df = ta.merge_data(traffic_df, events_df)

# %% [markdown]
# ### Exploratory Data Analysis - Summary Plots

# %%
ta.run_eda(merged_df)

# %% [markdown]
# ### Exploratory Data Analysis - Advanced Visualizations

# %%
ta.run_eda_plots(merged_df)

# %% [markdown]
# ### Gradient Boosting Regressor for Traffic Volume

# %%
ta.model_gbr(merged_df)

# %% [markdown]
# ### Heatmap by Street and Direction

# %%
ta.volume_heatmap(merged_df)

# %% [markdown]
# ### Classification Models: Weekend vs Weekday

# %%
ta.model_classifiers(merged_df)
